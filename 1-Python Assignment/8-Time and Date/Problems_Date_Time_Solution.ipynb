# %% [markdown]
# ### Python Datetime - Exercises

# %% [markdown]
# #### 1. Write a Python script to display the
# * Current date and time
# * Current year
# * Month of year
# * Week number of the year
# * Weekday of the week
# * Day of year
# * Day of the month
# * Day of week

# %%
import time
import datetime
print("Current date and time: " , datetime.datetime.now())
print("Current year: ", datetime.date.today().strftime("%Y"))
print("Month of year: ", datetime.date.today().strftime("%B"))
print("Week number of the year: ", datetime.date.today().strftime("%W"))
print("Weekday of the week: ", datetime.date.today().strftime("%w"))
print("Day of year: ", datetime.date.today().strftime("%j"))
print("Day of the month : ", datetime.date.today().strftime("%d"))
print("Day of week: ", datetime.date.today().strftime("%A"))
# Out:
# Current date and time:  2022-12-22 06:45:34.013821
# Current year:  2022
# Month of year:  December
# Week number of the year:  51
# Weekday of the week:  4
# Day of year:  356
# Day of the month :  22
# Day of week:  Thursday

# %% [markdown]
# #### 2. Write a Python program to determine whether a given year is a leap year.

# %%
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year isn't a leap year!")
# Out:
# Enter year to be checked:2004
# The year is a leap year!

# %% [markdown]
# #### 3. Write a Python program to convert a string to datetime.
# * Sample String : Jan 1 2014 2:43PM
# * Expected Output : 2014-07-01 14:43:00

# %%
import datetime

# Function to convert string to datetime
def convert(date_time):
	format = '%b %d %Y %I:%M%p' # The format
	datetime_str = datetime.datetime.strptime(date_time, format)

	return datetime_str


# Driver code
date_time = 'Dec 22 2022 12:19PM'
print(convert(date_time))
# Out:
# 2022-12-22 12:19:00

# %% [markdown]
# #### 4. Write a Python program to subtract five days from current date

# %%
from datetime import date, timedelta
dt = date.today() - timedelta(5)
print('Current Date :',date.today())
print('5 days before Current Date :',dt)
# Out:
# Current Date : 2022-12-22
# 5 days before Current Date : 2022-12-17

# %% [markdown]
# #### 5.Write a Python program to convert unix timestamp string to readable date

# %%
# Importing datetime module
import datetime

# Calling the fromtimestamp() function to
# extract datetime from the given timestamp

# Calling the strftime() function to convert
# the extracted datetime into its string format
print(datetime.datetime.fromtimestamp(int("1294113662")) #https://www.unixtimestamp.com/ SECONDS SINCE JAN 01 1970. (UTC) 12:23:54 PM
	.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2011-01-04 04:01:02

# %% [markdown]
# #### 6. Write a Python program to print yesterday, today, tomorrow.

# %%
import datetime 
today = datetime.date.today()
yesterday = today - datetime.timedelta(days = 1)
tomorrow = today + datetime.timedelta(days = 1) 
print('Yesterday : ',yesterday)
print('Today : ',today)
print('Tomorrow : ',tomorrow)
# Out:
# Yesterday :  2022-12-21
# Today :  2022-12-22
# Tomorrow :  2022-12-23

# %% [markdown]
# #### 7. Write a Python program to get week number

# %%
import datetime
print(datetime.date(2022, 12, 22).isocalendar()[1])
# Out:
# 51

# %% [markdown]
# #### 8.Write a Python program to select all the Sundays of a specified year

# %%
from datetime import date, timedelta

def all_sundays(year):
# January 1st of the given year
       dt = date(year, 1, 1)
# First Sunday of the given year       
       dt += timedelta(days = 6 - dt.weekday())  
       while dt.year == year:
          yield dt
          dt += timedelta(days = 7)
          
for s in all_sundays(2022):
   print(s)
# Out:
# 2022-01-02
# 2022-01-09
# 2022-01-16
# 2022-01-23
# 2022-01-30
# 2022-02-06
# 2022-02-13
# 2022-02-20
# 2022-02-27
# 2022-03-06
# 2022-03-13
# 2022-03-20
# 2022-03-27
# 2022-04-03
# 2022-04-10
# 2022-04-17
# 2022-04-24
# 2022-05-01
# 2022-05-08
# 2022-05-15
# 2022-05-22
# 2022-05-29
# 2022-06-05
# 2022-06-12
# 2022-06-19
# 2022-06-26
# 2022-07-03
# 2022-07-10
# 2022-07-17
# 2022-07-24
# 2022-07-31
# 2022-08-07
# 2022-08-14
# 2022-08-21
# 2022-08-28
# 2022-09-04
# 2022-09-11
# 2022-09-18
# 2022-09-25
# 2022-10-02
# 2022-10-09
# 2022-10-16
# 2022-10-23
# 2022-10-30
# 2022-11-06
# 2022-11-13
# 2022-11-20
# 2022-11-27
# 2022-12-04
# 2022-12-11
# 2022-12-18
# 2022-12-25

# %% [markdown]
# #### 9. Write a Python program to get the last day of a specified year and month

# %%
import calendar
year = 2015
month = 2
print(calendar.monthrange(year, month)[1])
# Out:
# 28
